# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name:  James M. Irving
# * Student pace:  full time
# * Scheduled project review date/time:  03/08/19 at 12pm
# * Instructor name: Jeff Herman
# * Blog post URL: _Brandon has instructed us to focus on the jupyter notebook and presetation now and to write up the blog post following our review_
# ___

# %% [markdown]
# # Outline of Data Processing and Analysis(using OSEMN model)
#
# 1. **OBTAIN:**
#     **Import data, inspect, check for datatypes to convert and null values**
#     - Display header and info
#     - Drop any unneeded columns (df.drop(['col1','col2'],axis=1)
#
# 2. **SCRUB: cast data types, identify outliers, check for multicollinearity, normalize data**
#     - Check and cast data types
#         - [x] Check for #'s that are store as objects (df.info())
#             - when converting to #'s, look for odd values (like many 0's), or strings that can't be converted
#             - Decide how to deal weird/null values (df.unique(), df.isna().sum(), df.describe()-min/max, etc
#         - [x]  Check for categorical variables stored as integers
#     - [x] Check for missing values  (df.isna().sum())
#         - Can drop rows or colums
#         - For missing numeric data with median or bin/convert to categorical
#         - For missing categorical data: make NaN own category OR replace with most common category
#     - [X] Check for multicollinearity
#          - use seaborn to make correlation matrix plot [Evernote Link](https://www.evernote.com/l/AArNyaEwjA5JUL6I9PazHs_ts_hU-m7ja1I/)
#         - Good rule of thumb is anything over 0.75 corr is high, remove the variable that has the most correl with the largest # of variables
#     - [x] Normalize data (may want to do after some exploring)
#         - Most popular is Z-scoring (but won't fix skew)
#         - Can log-transform to fix skewed data
#
#
# 3. **EXPLORE:Check distributions, outliers, etc**
#     - [x] Check scales, ranges (df.describe())
#     - [x] Check histograms to get an idea of distributions (df.hist()) and dat transformations to perform
#         - Can also do kernel density estimates
#     - [x] Use scatterplots to check for linearity and possible categorical variables (df.plot(kind-'scatter')
#         - categoricals will look like vertical lines
#     - [x] Use pd.plotting.scatter_matrix to visualize possible relationships
#     - [x] Check for linearity
#
#
# 4. **FIT AN INITIAL MODEL:**
#     - Various forms, detail later...
#     - **Assessing the model:**
#         - Assess parameters (slope,intercept)
#         - Check if the model explains the variation in the data (RMSE, F, R_square)
#         - *Are the coeffs, slopes, intercepts in appropriate units?*
#         - *Whats the impact of collinearity? Can we ignore?*
# 5. **Revise the fitted model**
#     - Multicollinearity is big issue for lin regression and cannot fully remove it
#     - Use the predictive ability of model to test it (like R2 and RMSE)
#     - Check for missed non-linearity
# 6. **Holdout validation / Train/test split**
#     - use sklearn train_test_split
# ___

# %% [markdown]
# <h1>Table of Contents (Links)<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Final-Project-Submission" data-toc-modified-id="Final-Project-Submission-1">Final Project Submission</a></span></li><li><span><a href="#Outline-of-Data-Processing-and-Analysis(using-OSEMN-model)" data-toc-modified-id="Outline-of-Data-Processing-and-Analysis(using-OSEMN-model)-2">Outline of Data Processing and Analysis(using OSEMN model)</a></span></li><li><span><a href="#OBTAIN:" data-toc-modified-id="OBTAIN:-3">OBTAIN:</a></span><ul class="toc-item"><li><span><a href="#Define-functions-to-be-used" data-toc-modified-id="Define-functions-to-be-used-3.1">Define functions to be used</a></span></li></ul></li><li><span><a href="#SCRUB:" data-toc-modified-id="SCRUB:-4">SCRUB:</a></span><ul class="toc-item"><li><span><a href="#Initial-inspection-of-dataframe,-datatypes,-and-null-values" data-toc-modified-id="Initial-inspection-of-dataframe,-datatypes,-and-null-values-4.1">Initial inspection of dataframe, datatypes, and null values</a></span></li><li><span><a href="#Recast-variables-and-identify-null-values" data-toc-modified-id="Recast-variables-and-identify-null-values-4.2">Recast variables and identify null values</a></span></li><li><span><a href="#Identifying-numerical-data-better-analyzed-as-categorical" data-toc-modified-id="Identifying-numerical-data-better-analyzed-as-categorical-4.3">Identifying numerical data better analyzed as categorical</a></span><ul class="toc-item"><li><span><a href="#QUESTION-1:-Which-predictors-should-be-analyzed-as-continuous-data,-vs-binned/categorical-data?" data-toc-modified-id="QUESTION-1:-Which-predictors-should-be-analyzed-as-continuous-data,-vs-binned/categorical-data?-4.3.1">QUESTION 1: Which predictors should be analyzed as continuous data, vs binned/categorical data?</a></span></li><li><span><a href="#LISTS-OF-VARIABLE-NAMES-BY-TYPE-TO-REFERENCE" data-toc-modified-id="LISTS-OF-VARIABLE-NAMES-BY-TYPE-TO-REFERENCE-4.3.2">LISTS OF VARIABLE NAMES BY TYPE TO REFERENCE</a></span></li><li><span><a href="#Coarse-Binning-Numerical-Data" data-toc-modified-id="Coarse-Binning-Numerical-Data-4.3.3">Coarse-Binning Numerical Data</a></span></li><li><span><a href="#Adding-sqft_basement-and-sqft_above" data-toc-modified-id="Adding-sqft_basement-and-sqft_above-4.3.4">Adding sqft_basement and sqft_above</a></span></li></ul></li><li><span><a href="#Checking-for-multicolinearity-before-converting-categories" data-toc-modified-id="Checking-for-multicolinearity-before-converting-categories-4.4">Checking for multicolinearity before converting categories</a></span><ul class="toc-item"><li><span><a href="#QUESTION-2:-Which-predictors-are-closely-related-and-should-be-considered-to-be-dropped-from-the-analyses?" data-toc-modified-id="QUESTION-2:-Which-predictors-are-closely-related-and-should-be-considered-to-be-dropped-from-the-analyses?-4.4.1">QUESTION 2: Which predictors are closely related and should be considered to be dropped from the analyses?</a></span></li><li><span><a href="#List-of-variables-to-be-dropped-from-analyses" data-toc-modified-id="List-of-variables-to-be-dropped-from-analyses-4.4.2">List of variables to be dropped from analyses</a></span></li></ul></li></ul></li><li><span><a href="#EXPLORE:" data-toc-modified-id="EXPLORE:-5">EXPLORE:</a></span><ul class="toc-item"><li><span><a href="#Examine-basic-descriptive-stats" data-toc-modified-id="Examine-basic-descriptive-stats-5.1">Examine basic descriptive stats</a></span></li><li><span><a href="#Visualizing-numerical-data" data-toc-modified-id="Visualizing-numerical-data-5.2">Visualizing numerical data</a></span><ul class="toc-item"><li><span><a href="#Preliminary-linear-regression-visualizations" data-toc-modified-id="Preliminary-linear-regression-visualizations-5.2.1">Preliminary linear regression visualizations</a></span></li></ul></li><li><span><a href="#Visualizing-categorical-data" data-toc-modified-id="Visualizing-categorical-data-5.3">Visualizing categorical data</a></span><ul class="toc-item"><li><span><a href="#QUESTION-3:-Which-categorical-variables-show-the-greatest-potential-as-predictors?" data-toc-modified-id="QUESTION-3:-Which-categorical-variables-show-the-greatest-potential-as-predictors?-5.3.1">QUESTION 3: Which categorical variables show the greatest potential as predictors?</a></span></li></ul></li><li><span><a href="#Normalizing-and-transforming-data" data-toc-modified-id="Normalizing-and-transforming-data-5.4">Normalizing and transforming data</a></span></li></ul></li><li><span><a href="#FIT-AN-INITIAL-MODEL:" data-toc-modified-id="FIT-AN-INITIAL-MODEL:-6">FIT AN INITIAL MODEL:</a></span><ul class="toc-item"><li><span><a href="#PRELIMINARY-UNIVARIATE-LINEAR-REGRESSION-MODELING" data-toc-modified-id="PRELIMINARY-UNIVARIATE-LINEAR-REGRESSION-MODELING-6.1">PRELIMINARY UNIVARIATE LINEAR REGRESSION MODELING</a></span><ul class="toc-item"><li><span><a href="#CONCATENATING-ANALYSIS-DATASET" data-toc-modified-id="CONCATENATING-ANALYSIS-DATASET-6.1.1">CONCATENATING ANALYSIS DATASET</a></span></li></ul></li><li><span><a href="#MULTIVARIATE-REGRESSIONS" data-toc-modified-id="MULTIVARIATE-REGRESSIONS-6.2">MULTIVARIATE REGRESSIONS</a></span></li></ul></li><li><span><a href="#Final-Model" data-toc-modified-id="Final-Model-7">Final Model</a></span><ul class="toc-item"><li><span><a href="#Predictor-Coefficients-&amp;-Their-Affect-On-Sales-Price" data-toc-modified-id="Predictor-Coefficients-&amp;-Their-Affect-On-Sales-Price-7.1">Predictor Coefficients &amp; Their Affect On Sales Price</a></span></li></ul></li><li><span><a href="#Future-Directions" data-toc-modified-id="Future-Directions-8">Future Directions</a></span></li></ul></div>

# %% [markdown]
# ---

# %% [markdown]
# # OBTAIN:
#  - Import required packages, read in dataframe, and definefunctions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.style.use('seaborn')
import statsmodels.api as sm
import statsmodels.formula.api as smf

df = pd.read_csv('kc_house_data.csv')   
df = df.drop('id',axis=1)
# df.drop(['lat','long'],axis=1,inplace=True)

# %%
from scipy.stats import normaltest as normtest 
#in order to run normality test using combination of D'Agostino and Pearson's
# H0 is that the data comes from normal so p<.05 indicates NOT normal
# stat,p-value = normtest(a,)

# %% [markdown]
# ## Define functions to be used

# %%
# Check columns will 
def check_column(series):
    print(f"Column: df['{series.name}']':")
    print(f"dtype: {series.dtype}")
    print(f"isna: {series.isna().sum()} out of {len(series)} - {round(series.isna().sum()/len(series),3)}%")
    print(f'\nUnique non-na values:') #,df['waterfront'].unique())
    print(series.value_counts())

# %%
# define log + z-score
def log_z(col):
    
    col = np.array(col)
    logcol = np.log(col)
#     logcol=np.log(col,where=[col!=0])
#     logcol[logcol==0] = np.nan
#     col[col==0]=np.nan
    
    
    zlogcol = (logcol-np.mean(logcol))/np.sqrt(np.var(logcol))
    return zlogcol

# %%
#     ## TESTING LOG TRANSFORM IGNORING 0's
#     test_data = df['sqft_basement'].copy()
#     testZ = log_z(test_data)
#     pd.DataFrame(testZ).describe()
#     # test_data.describe()

#     # col = np.array(test_data)
#     # col[col==0] = np.nan

#     # logcol=np.log(col,where=[col!=0])
#     # logcol[logcol==0] = np.nan


#     # def log_z(col):

#     #     col = np.array(col)
#     #     logcol=np.log(col,where=[col!=0])
#     #     logcol[logcol==0] = np.nan
#     # #     col[col==0]=np.nan


#     #     zlogcol = (logcol-np.mean(logcol))/np.sqrt(np.var(logcol))
#     #     return zlogcol

# %%
# MULTIPLOT
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def multiplot(df):

    sns.set(style="white")

    # Compute the correlation matrix
#     df_corr = df.drop('price',axis=1)
    corr = df.corr()

    # Generate a mask for the upper triangle
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(16, 16))

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(corr, mask=mask, annot=True, cmap=cmap, center=0,
                
    square=True, linewidths=.5, cbar_kws={"shrink": .5}) #

# %%
# Plots histogram and scatter (vs price) side by side
def plot_hist_scat(df,target='price',stats=True):
    plt.style.use('bmh')
    results = [['column','K_square','p-val']]

    for column in df.describe():
    # for column in df:

        fig = plt.figure(figsize=(8,3) )#plt.figaspect(0.5))#(5,4))
        ax1 = fig.add_subplot(121)
        ax1.hist(df[column],density=True,label = column+' histogram',bins=20)
    #     ax1.kde()
        ax1.set(title=column.capitalize())
        ax1.legend()
    #     plt.show()
        ax2 = fig.add_subplot(122)
        ax2.scatter(x=df[column], y=df[target],label = column+' vs price',marker='.')
        ax2.set(title=column.capitalize())
        ax2.legend()

        fig.tight_layout()
        if stats==True:
            stat, p = normtest(df[column])
#             print(f'Normality test for {column}:K_square = {stat}, p-value = {p}')

            results.append([column,stat, p])
    return pd.DataFrame(results)

# %% [markdown]
# # SCRUB:
#
# ## Initial inspection of dataframe, datatypes, and null values

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above sqft_basement  yr_built  \
# 0         NaN   0.0          3      7        1180           0.0      1955
# 1         0.0   0.0          3      7        2170         400.0      1951
# 2         0.0   0.0          3      6         770           0.0      1933
# 3         0.0   0.0          5      7        1050         910.0      1965
# 4         0.0   0.0          3      8        1680           0.0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0           0.0    98178  47.5112 -122.257           1340        5650
# 1        1991.0    98125  47.7210 -122.319           1690        7639
# 2           NaN    98028  47.7379 -122.233           2720        8062
# 3           0.0    98136  47.5208 -122.393           1360        5000
# 4           0.0    98074  47.6168 -122.045           1800        7503

# %%
# Display DataFrame Infro
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 20 columns):
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(10), object(2)
# memory usage: 3.3+ MB

# %%
# Check for columns with null values (remember strings/objects are not counted here)
res = df.isna().sum()
print(res[res>0])
# Waterfront, view, yr_renovated have missing values
# Out:
# waterfront      2376
# view              63
# yr_renovated    3842
# dtype: int64

# %% [markdown]
# ## Recast variables and identify null values
# - From examining the df.info and df.isna().sum(), there is 1 numerical data column that is currently text/object data type.
#     - I will address these first since they would be excluded from preliminary visualizations.
# - There are also null values to address in waterfront, view, and yr_renovated
# - The Date column will be recast as datetime

# %% [markdown]
# #### sqft_basement

# %%
# RECASTING SQFT_BASEMENT
# Checking why sqft_basement might be an object:
df['sqft_basement'].value_counts()
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
# 400.0       184
# 1000.0      148
# 900.0       142
# 300.0       142
# 200.0       105
# 750.0       104
# 480.0       103
# 530.0       103
# 450.0       103
# 720.0        98
# 620.0        90
# 580.0        84
# 840.0        83
# 420.0        81
# 860.0        79
# 1100.0       78
# 670.0        78
# 550.0        76
# 780.0        76
# 650.0        75
# 240.0        74
# 680.0        73
# 380.0        73
# 850.0        72
#           ...
# 4130.0        1
# 1852.0        1
# 2610.0        1
# 2850.0        1
# 1024.0        1
# 475.0         1
# 1913.0        1
# 374.0         1
# 935.0         1
# 946.0         1
# 506.0         1
# 143.0         1
# 2400.0        1
# 2490.0        1
# 2120.0        1
# 2810.0        1
# 2310.0        1
# 1880.0        1
# 1481.0        1
# 2600.0        1
# 861.0         1
# 2180.0        1
# 65.0          1
# 207.0         1
# 792.0         1
# 3480.0        1
# 2130.0        1
# 1990.0        1
# 2190.0        1
# 2300.0        1
# Name: sqft_basement, Length: 304, dtype: int64

# %% [markdown]
# - **sqft_basement is current an object, needs to be converted to int**
#     - Need to replace the 454 '?' values
#     - There are a lot of 0's, for sqft_basement. Not sure if I should keep them in the dataset. I am for now.
#     - _Note: I originally replaced the ?'s with 0's, but am re-running the dataset with them dropped altogether._

# %%
# Removing rows with ? for sqft_basement
# df['sqft_basement']=df['sqft_basement'].astype(float)

df['sqft_basement']=df['sqft_basement'].replace(to_replace = '?',value=np.nan) #,inplace=True)
df.dropna(axis=0,subset=['sqft_basement'],inplace=True)
df['sqft_basement'].isna().sum()

df['sqft_basement'] = df['sqft_basement'].astype('float')
# Original choice
# num_df['sqft_basement'].replace('?','0.0',inplace=True)
# num_df['sqft_basement'].replace('0','0.0',inplace=True) # I chose to assume

# %%
df['sqft_basement'].value_counts()
# Out:
# 0.0       12826
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
# 400.0       184
# 1000.0      148
# 900.0       142
# 300.0       142
# 200.0       105
# 750.0       104
# 450.0       103
# 530.0       103
# 480.0       103
# 720.0        98
# 620.0        90
# 580.0        84
# 840.0        83
# 420.0        81
# 860.0        79
# 670.0        78
# 1100.0       78
# 780.0        76
# 550.0        76
# 650.0        75
# 240.0        74
# 680.0        73
# 380.0        73
# 850.0        72
# 360.0        72
#           ...
# 2600.0        1
# 2610.0        1
# 276.0         1
# 274.0         1
# 1245.0        1
# 143.0         1
# 266.0         1
# 862.0         1
# 2180.0        1
# 415.0         1
# 243.0         1
# 1135.0        1
# 1525.0        1
# 3000.0        1
# 172.0         1
# 225.0         1
# 518.0         1
# 935.0         1
# 1920.0        1
# 1930.0        1
# 1990.0        1
# 588.0         1
# 1548.0        1
# 2390.0        1
# 602.0         1
# 915.0         1
# 295.0         1
# 1281.0        1
# 2130.0        1
# 906.0         1
# Name: sqft_basement, Length: 303, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 20 columns):
# date             21143 non-null object
# price            21143 non-null float64
# bedrooms         21143 non-null int64
# bathrooms        21143 non-null float64
# sqft_living      21143 non-null int64
# sqft_lot         21143 non-null int64
# floors           21143 non-null float64
# waterfront       18804 non-null float64
# view             21082 non-null float64
# condition        21143 non-null int64
# grade            21143 non-null int64
# sqft_above       21143 non-null int64
# sqft_basement    21143 non-null float64
# yr_built         21143 non-null int64
# yr_renovated     17389 non-null float64
# zipcode          21143 non-null int64
# lat              21143 non-null float64
# long             21143 non-null float64
# sqft_living15    21143 non-null int64
# sqft_lot15       21143 non-null int64
# dtypes: float64(9), int64(10), object(1)
# memory usage: 3.4+ MB

# %%
# Check for columns with null values (remember strings/objects are not counted here)
res = df.isna().sum()
print(res[res>0])
# Waterfront, view, yr_renovated have missing values
# Out:
# waterfront      2339
# view              61
# yr_renovated    3754
# dtype: int64

# %% [markdown]
# #### View
# - Replace the 61 null values with appropriate value for data type

# %%
df['view'].value_counts()
# Out:
# 0.0    19018
# 2.0      930
# 3.0      496
# 1.0      327
# 4.0      311
# Name: view, dtype: int64

# %%
df['view'].fillna(0.0,inplace=True)
# df['view'] = df['view'].astype('int')
df['view'].value_counts()
# Out:
# 0.0    19079
# 2.0      930
# 3.0      496
# 1.0      327
# 4.0      311
# Name: view, dtype: int64

# %%
#Recheck whole df
df.isna().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2339
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3754
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# #### Waterfront
# - Waterfront has 2339 null values to replace.

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    18662
# 1.0      142
# Name: waterfront, dtype: int64

# %%
# Fill Null Values with 0.0
df['waterfront'] = df['waterfront'].fillna(0.0)

# %%
# Recheck whole df
df.isna().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3754
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %% [markdown]
# #### yr_renovated
# - yr_renovated has 3754 null values
#     - Presumably this is because the homes were never renovated
#     - Will replace with 0.0

# %%
# Verify that there are 0.0's in dataset already for none-renovated homes
df['yr_renovated'].describe()
# Out:
# count    17389.000000
# mean        82.991949
# std        398.481819
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       2015.000000
# Name: yr_renovated, dtype: float64

# %%
# Fill in yr_renovated
df['yr_renovated'] = df['yr_renovated'].fillna(0.0)

# %%
# Recheck for null values
df.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# #### Date

# %%
## Recast df['date'] as datetime
df['date'] = pd.to_datetime(df['date'])
df['date'].nunique()
# Out:
# 372

# %% [markdown]
# #### SCRUBBING THUS FAR REVIEW
# - Null values have been replaced, objects converted to numbers, dates recase.
# - Next to identify which numerical columns may be better analyzed as categories

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 20 columns):
# date             21143 non-null datetime64[ns]
# price            21143 non-null float64
# bedrooms         21143 non-null int64
# bathrooms        21143 non-null float64
# sqft_living      21143 non-null int64
# sqft_lot         21143 non-null int64
# floors           21143 non-null float64
# waterfront       21143 non-null float64
# view             21143 non-null float64
# condition        21143 non-null int64
# grade            21143 non-null int64
# sqft_above       21143 non-null int64
# sqft_basement    21143 non-null float64
# yr_built         21143 non-null int64
# yr_renovated     21143 non-null float64
# zipcode          21143 non-null int64
# lat              21143 non-null float64
# long             21143 non-null float64
# sqft_living15    21143 non-null int64
# sqft_lot15       21143 non-null int64
# dtypes: datetime64[ns](1), float64(9), int64(10)
# memory usage: 3.4 MB

# %% [markdown]
# ## Identifying numerical data better analyzed as categorical

# %% [markdown]
# ### QUESTION 1: Which predictors should be analyzed as continuous data, vs binned/categorical data?

# %%
fig = plot_hist_scat(df)

# %% [markdown]
# #### ANSWER 1:
# - Notes on histograms and scatterplots
# #### First, to comment on scatter plots that are indicative of categorical data:
# - **Clear columns to be analyzed as categorical data:**
#     - Waterfront
#     - View
#     - Condition
#     - Grade
#     - Zipcode
# - **Columns that look categorical are intuitively numerical data** (e.g. 2 floors is indeed  double 1 floor)
#     - Floors
#     - Bedrooms
#     - Bathrooms
# - **Columns that may be best analyzed by binning and casting as categorical data**
#     - Yr_built
#     - Yr_renovated
#         - Could be binned by decade
#         - Could be classified as simply renovated or not.
# - **Numerical columns** (that may be best analyzed as such)
#     - All sqft categories
#     - Note: moved sqft_basement to binned category to deal with 0's, also added sqft_above to accompany it
# - **Numerical columns that cannot easily be used**
#     - Lat
#     - Long
#     - Date
#
#
# #### Second, to comment on distributions
# - The target variable, price, seems a bit skewed and _may_ be better analyzed as log-transformed.
#     - Try both log-transformed and unaltered
# - All sqft columns seem to be skewed and should be transformed. (log)

# %% [markdown]
# ### LISTS OF VARIABLE NAMES BY TYPE TO REFERENCE

# %%
# Create tuples with columns names of categorical variables for easy extraction 
cat_vars = ('grade','condition','view','waterfront','zipcode')
ambig_vars = ('floors','bedrooms','bathrooms')
vars_to_bin = ('yr_built','yr_renovated','sqft_above','sqft_basement')
num_vars = ('sqft_living', 'sqft_lot','sqft_living15', 'sqft_lot15')

# %%
# # Separate categorical variables and numerical for preprocessing

# cat_vars = ['date','floors','bedrooms','bathrooms','grade','condition','view','waterfront','zipcode','yr_built','yr_renovated']
# num_df = df.copy().drop(cat_vars, axis=1)
# # df.drop(cat_vars, axis=1)
# cat_df = df[cat_vars].copy()

# %% [markdown]
# ### Coarse-Binning Numerical Data
# - yr_built, yr_renovated
# - Added sqft_basement due to 0 values
# - Added sqft_above to accompany basement

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()

# %% [markdown]
# #### df['yr_built']

# %%
# Check the min and max of the yr variables for binning range
df[['yr_built','yr_renovated']].describe()
# Out:
#            yr_built  yr_renovated
# count  21143.000000  21143.000000
# mean    1971.023223     68.256492
# std       29.321938    362.765827
# min     1900.000000      0.000000
# 25%     1952.000000      0.000000
# 50%     1975.000000      0.000000
# 75%     1997.000000      0.000000
# max     2015.000000   2015.000000

# %%
## Bin yr_built then make yr_built category

# yr_built min is 1900, max is 2015
bins = list(range(1900,2030,10))

# df['yr_built'].hist(bins=bins)
bins_yrbuilt = pd.cut(df['yr_built'], bins) # Cut into bins

# %%
df['bins_yrbuilt'] = bins_yrbuilt.cat.as_unordered()

# %%
# Inspecting the binned data counts
df['bins_yrbuilt'].value_counts()
# Out:
# (2000, 2010]    3364
# (1960, 1970]    2489
# (1950, 1960]    2419
# (1970, 1980]    2356
# (1980, 1990]    2305
# (1990, 2000]    2093
# (1940, 1950]    1813
# (1920, 1930]    1145
# (2010, 2020]    1068
# (1910, 1920]     750
# (1900, 1910]     677
# (1930, 1940]     580
# Name: bins_yrbuilt, dtype: int64

# %% [markdown]
# #### df['yr_renovated']'

# %%
## Bin and convert yr_renovated to category

# Range in describe had 0 as a minimum, for houses that were not renovated 
# To get real min/max, exclude 0's
# Bin yr_renovated then make yr_renovated category
print(df['yr_renovated'][df['yr_renovated']>0].min())
print(df['yr_renovated'][df['yr_renovated']>0].max())
# Out:
# 1934.0
# 2015.0

# %%
## Bin yr_renovated by decade, make 0 a NaN value.

# Range of years (min = 1934, max=2015)
bins = list(range(1930,2030,10))

bins_yrrenovated = pd.cut(df['yr_renovated'], bins) # Cut into bins
bins_yrrenovated.value_counts()
# Out:
# (2000, 2010]    210
# (1990, 2000]    145
# (1980, 1990]    135
# (2010, 2020]    131
# (1970, 1980]     41
# (1960, 1970]     35
# (1950, 1960]     18
# (1940, 1950]      5
# (1930, 1940]      3
# Name: yr_renovated, dtype: int64

# %%
bins_yrrenovated.isna().sum()
# Out:
# 20420

# %%
df['bins_yrrenovated'] = bins_yrrenovated.cat.as_unordered()

# %%
df['bins_yrrenovated'].replace(np.NaN,"NaN",inplace=True)
df['bins_yrrenovated'] = df['bins_yrrenovated'] .astype('category')
df['bins_yrrenovated'].value_counts()
# Out:
# NaN                 20420
# (2000.0, 2010.0]      210
# (1990.0, 2000.0]      145
# (1980.0, 1990.0]      135
# (2010.0, 2020.0]      131
# (1970.0, 1980.0]       41
# (1960.0, 1970.0]       35
# (1950.0, 1960.0]       18
# (1940.0, 1950.0]        5
# (1930.0, 1940.0]        3
# Name: bins_yrrenovated, dtype: int64

# %% [markdown]
# **Note: I originally converted these categories to labeled columns using LabelEncoder(), then dropped the original columns,  but I decided to wait until later to perform this step (right before modeling)**

# %%
# df['lb_bin_yrbuilt'] = lb_make.fit_transform(df['bins_yrbuilt].astype('str'))
# df['lb_bin_yrrenovated'] = lb_make.fit_transform(df['bins_yrrenovated'].astype('str'))

# %%
# Confirm new columns before dropping old
# cat_df.drop('yr_renovated',axis=1,inplace=True)
# Decided to leave the original column in the dataframe for now. 
# Confirm the new column before dropping the old
# df.drop('yr_built',axis=1,inplace=True)

# %% [markdown]
# ### Adding sqft_basement and sqft_above
# #### sqft_basement

# %%
df[['sqft_basement','sqft_above']].describe()
# Out:
#        sqft_basement    sqft_above
# count   21143.000000  21143.000000
# mean      291.851724   1789.069006
# std       442.498337    828.409769
# min         0.000000    370.000000
# 25%         0.000000   1200.000000
# 50%         0.000000   1560.000000
# 75%       560.000000   2210.000000
# max      4820.000000   9410.000000

# %%
# sqft_basement
bins = list(range(0,5000,500))

cut_basement = df['sqft_basement'].replace(0,np.nan)
bins_sqftbase = pd.cut(cut_basement, bins=bins) # Cut into bins
bins_sqftbase_cat = bins_sqftbase.cat.as_unordered()
bins_sqftbase_cat.replace(np.nan,'NaN',inplace=True)
df['bins_sqftbasement']=bins_sqftbase_cat.astype('category')

# bins_sqftbase_cat.value_counts()
df['bins_sqftbasement'].value_counts()
# Out:
# NaN                 12827
# (500.0, 1000.0]      3865
# (0.0, 500.0]         2626
# (1000.0, 1500.0]     1481
# (1500.0, 2000.0]      270
# (2000.0, 2500.0]       59
# (2500.0, 3000.0]       11
# (3000.0, 3500.0]        3
# (4000.0, 4500.0]        1
# Name: bins_sqftbasement, dtype: int64

# %% [markdown]
# #### sqft_above

# %%
# sqft_above
bins = list(range(0,9500,500))

cut_above = df['sqft_above'].replace(0,np.nan)
bins_sqftabove = pd.cut(cut_above, bins=bins) # Cut into bins
bins_sqftabove_cat = bins_sqftabove.cat.as_unordered()
bins_sqftabove_cat.replace(np.nan,'NaN',inplace=True)
df['bins_sqftabove']=bins_sqftabove_cat.astype('category')

# bins_sqftbase_cat.value_counts()
# df['bins_sqftabove'].value_counts().hist()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 24 columns):
# date                 21143 non-null datetime64[ns]
# price                21143 non-null float64
# bedrooms             21143 non-null int64
# bathrooms            21143 non-null float64
# sqft_living          21143 non-null int64
# sqft_lot             21143 non-null int64
# floors               21143 non-null float64
# waterfront           21143 non-null float64
# view                 21143 non-null float64
# condition            21143 non-null int64
# grade                21143 non-null int64
# sqft_above           21143 non-null int64
# sqft_basement        21143 non-null float64
# yr_built             21143 non-null int64
# yr_renovated         21143 non-null float64
# zipcode              21143 non-null int64
# lat                  21143 non-null float64
# long                 21143 non-null float64
# sqft_living15        21143 non-null int64
# sqft_lot15           21143 non-null int64
# bins_yrbuilt         21059 non-null category
# bins_yrrenovated     21143 non-null category
# bins_sqftbasement    21143 non-null category
# bins_sqftabove       21143 non-null category
# dtypes: category(4), datetime64[ns](1), float64(9), int64(10)
# memory usage: 3.5 MB

# %% [markdown]
# ## Checking for multicolinearity before converting categories
# ### QUESTION 2: Which predictors are closely related and should be considered to be dropped from the analyses?

# %%
# Plot correlation  heatmaps for all data 
to_drop = ['price','lat','long']
multiplot(df.drop(to_drop,axis=1))

# %% [markdown]
# #### ANSWER 2:
# - Sqft_living is highly correlated with sqft_above (0.88), and also with sqft_living15
# - These correlations make sense sense since neighborhoods probably have similar construction.
#     -Original choice was to eliminate sqft_above, as sqft_living seemed a more intuitive comparison.
#     - ~~Decided to keep sqft_living since it makes more intuitive sense than to just think about square footage above ground~~
#     - Upon revisiting, keeping sqft_above and sqft_basement may be better for modeling.
#         - Decided to removed sqft_living

# %%
to_drop = ['price','lat','long','sqft_living']
multiplot(df.drop(to_drop,axis=1))

# %% [markdown]
# - **Much better results, with only 1 correlation above 0.76 (sqft_above vs grade)**
#     - This make intuitive sense as being separate predictors for house price and they are borderline cut-off (0.75) so will keep in data set for modeling.

# %% [markdown]
# ### List of variables to be dropped from analyses
# ```python
# # Code to use later:
# to_drop = ['lat','long','sqft_living']
# df.drop(to_drop,axis=1,inplace=True)
#
# # Code to covert later
# df['view'] = df['view'].astype('str')
# df['waterfront'] = df['waterfront'].astype('str')
# df['condition'] = df['condition'].astype('str')
# df['grade'] = df['grade'].astype('str')
# ```

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 24 columns):
# date                 21143 non-null datetime64[ns]
# price                21143 non-null float64
# bedrooms             21143 non-null int64
# bathrooms            21143 non-null float64
# sqft_living          21143 non-null int64
# sqft_lot             21143 non-null int64
# floors               21143 non-null float64
# waterfront           21143 non-null float64
# view                 21143 non-null float64
# condition            21143 non-null int64
# grade                21143 non-null int64
# sqft_above           21143 non-null int64
# sqft_basement        21143 non-null float64
# yr_built             21143 non-null int64
# yr_renovated         21143 non-null float64
# zipcode              21143 non-null int64
# lat                  21143 non-null float64
# long                 21143 non-null float64
# sqft_living15        21143 non-null int64
# sqft_lot15           21143 non-null int64
# bins_yrbuilt         21059 non-null category
# bins_yrrenovated     21143 non-null category
# bins_sqftbasement    21143 non-null category
# bins_sqftabove       21143 non-null category
# dtypes: category(4), datetime64[ns](1), float64(9), int64(10)
# memory usage: 3.5 MB

# %%
# Save copy of data in current form.
df.to_csv('scrubbed_data,csv')

# %% [markdown]
# # EXPLORE:
# - Re-examining the basic stats and distributions of the data.
# - Decide on transformations to perform
#     - Normalize afterwards.
# - Visually examine for possible relationships

# %% [markdown]
# ## Examine basic descriptive stats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 24 columns):
# date                 21143 non-null datetime64[ns]
# price                21143 non-null float64
# bedrooms             21143 non-null int64
# bathrooms            21143 non-null float64
# sqft_living          21143 non-null int64
# sqft_lot             21143 non-null int64
# floors               21143 non-null float64
# waterfront           21143 non-null float64
# view                 21143 non-null float64
# condition            21143 non-null int64
# grade                21143 non-null int64
# sqft_above           21143 non-null int64
# sqft_basement        21143 non-null float64
# yr_built             21143 non-null int64
# yr_renovated         21143 non-null float64
# zipcode              21143 non-null int64
# lat                  21143 non-null float64
# long                 21143 non-null float64
# sqft_living15        21143 non-null int64
# sqft_lot15           21143 non-null int64
# bins_yrbuilt         21059 non-null category
# bins_yrrenovated     21143 non-null category
# bins_sqftbasement    21143 non-null category
# bins_sqftabove       21143 non-null category
# dtypes: category(4), datetime64[ns](1), float64(9), int64(10)
# memory usage: 3.5 MB

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_renovated  zipcode      lat     long  \
# 0         0.0   0.0          3  ...           0.0    98178  47.5112 -122.257
# 1         0.0   0.0          3  ...        1991.0    98125  47.7210 -122.319
# 2         0.0   0.0          3  ...           0.0    98028  47.7379 -122.233
# 3         0.0   0.0          5  ...           0.0    98136  47.5208 -122.393
# 4         0.0   0.0          3  ...           0.0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  bins_yrbuilt  bins_yrrenovated  \
# 0           1340        5650  (1950, 1960]               NaN
# 1           1690        7639  (1950, 1960]  (1990.0, 2000.0]
# 2           2720        8062  (1930, 1940]               NaN
# 3           1360        5000  (1960, 1970]               NaN
# 4           1800        7503  (1980, 1990]               NaN
#
#    bins_sqftbasement    bins_sqftabove
# 0                NaN  (1000.0, 1500.0]
# 1       (0.0, 500.0]  (2000.0, 2500.0]
# 2                NaN   (500.0, 1000.0]
# 3    (500.0, 1000.0]  (1000.0, 1500.0]
# 4                NaN  (1500.0, 2000.0]
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.114300e+04  21143.000000  21143.000000  21143.000000  2.114300e+04
# mean   5.405107e+05      3.372558      2.116079   2080.920730  1.508714e+04
# std    3.680751e+05      0.924917      0.768531    918.547562  4.120920e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1430.000000  5.043000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.620000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.069550e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21143.000000  21143.000000  21143.000000  21143.000000  21143.000000
# mean       1.493591      0.006716      0.232654      3.409923      7.658279
# std        0.539249      0.081679      0.764064      0.650498      1.174253
# min        1.000000      0.000000      0.000000      1.000000      3.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#          sqft_above  sqft_basement      yr_built  yr_renovated       zipcode  \
# count  21143.000000   21143.000000  21143.000000  21143.000000  21143.000000
# mean    1789.069006     291.851724   1971.023223     68.256492  98077.868893
# std      828.409769     442.498337     29.321938    362.765827     53.535756
# min      370.000000       0.000000   1900.000000      0.000000  98001.000000
# 25%     1200.000000       0.000000   1952.000000      0.000000  98033.000000
# 50%     1560.000000       0.000000   1975.000000      0.000000  98065.000000
# 75%     2210.000000     560.000000   1997.000000      0.000000  98117.000000
# max     9410.000000    4820.000000   2015.000000   2015.000000  98199.000000
#
#                 lat          long  sqft_living15     sqft_lot15
# count  21143.000000  21143.000000    21143.00000   21143.000000
# mean      47.560274   -122.213876     1987.27139   12738.941967
# std        0.138591      0.140597      685.67034   27169.273663
# min       47.155900   -122.519000      399.00000     651.000000
# 25%       47.471250   -122.328000     1490.00000    5100.000000
# 50%       47.572000   -122.230000     1840.00000    7626.000000
# 75%       47.678200   -122.125000     2360.00000   10087.000000
# max       47.777600   -121.315000     6210.00000  871200.000000

# %% [markdown]
# #### Notes on basic statistics
# - Bedrooms has some very clear outliers (max is 33, but 75% quartile is only 4)
#     - May want to remove outliers after Z-scoring (Absolute Z-score > 3)
# - Same with bathrooms (8 is max, 75% quartile is only 2.5)
# - Same with sqft_living (max 13540, 75% quartile = 2550)
# - Also same with sqft_lot15, sqftliving15

# %% [markdown]
# ## Visualizing numerical data
# - Distributions and scatterplots
# - Note: May want to cast all categoricals as strings/categories for visualization
#     - Keeping as is for now

# %%
# INSPECTING NUMERICAL DATA DISTPLOTS + KDE
plt.style.use('seaborn')

for column in num_vars:
#     plot = sns.jointplot(column,"price",df,kind='kde')
    plot= sns.distplot(df[column],kde=True,label = column+' histogram')
#     plot = sns.boxplot(df[column],df['price'])
    title = column+' histogram'
    plt.title(title.title())
    plt.legend()
    plt.show()

# Uncomment below if want new scatter_matrix
# fig = pd.plotting.scatter_matrix(df_clean,figsize=(12,12))

# %% [markdown]
# #### Notes on distplots
# - Essentialy all numerical data seems to be at least slightly skewed.
#     -Log transform before analyses

# %% [markdown]
# ### Preliminary linear regression visualizations
# - Look for any possible relationships before data transformation
# - *Note: rows with 0 values were not included in this linear regression plots. (i.e. sqft_lot)

# %%
# INSPECTING REGRESSION PLOTS
plt.style.use('seaborn')

for column in num_vars:
#     plot = sns.jointplot(column,"price",df,kind='kde')
    df_plot = df.loc[df[column]>0]
    plot= sns.regplot(df_plot[column], df_plot['price'],marker='.') #kde=True,label = column+' histogram')
#     plot = sns.boxplot(df[column],df['price'])
    title = column+' linear regression'
    plt.title(title.title())
#     plt.legend()
    plt.show()

# %% [markdown]
# ## Visualizing categorical data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 24 columns):
# date                 21143 non-null datetime64[ns]
# price                21143 non-null float64
# bedrooms             21143 non-null int64
# bathrooms            21143 non-null float64
# sqft_living          21143 non-null int64
# sqft_lot             21143 non-null int64
# floors               21143 non-null float64
# waterfront           21143 non-null float64
# view                 21143 non-null float64
# condition            21143 non-null int64
# grade                21143 non-null int64
# sqft_above           21143 non-null int64
# sqft_basement        21143 non-null float64
# yr_built             21143 non-null int64
# yr_renovated         21143 non-null float64
# zipcode              21143 non-null int64
# lat                  21143 non-null float64
# long                 21143 non-null float64
# sqft_living15        21143 non-null int64
# sqft_lot15           21143 non-null int64
# bins_yrbuilt         21059 non-null category
# bins_yrrenovated     21143 non-null category
# bins_sqftbasement    21143 non-null category
# bins_sqftabove       21143 non-null category
# dtypes: category(4), datetime64[ns](1), float64(9), int64(10)
# memory usage: 3.5 MB

# %%
# Define list of all categorical variables 
binned_vars = ['bins_yrbuilt','bins_yrrenovated','bins_sqftbasement','bins_sqftabove']
all_cat_vars = list(cat_vars)+list(ambig_vars)+list(binned_vars)
all_cat_vars
# Out:
# ['grade',
#  'condition',
#  'view',
#  'waterfront',
#  'zipcode',
#  'floors',
#  'bedrooms',
#  'bathrooms',
#  'bins_yrbuilt',
#  'bins_yrrenovated',
#  'bins_sqftbasement',
#  'bins_sqftabove']

# %% [markdown]
# ### QUESTION 3: Which categorical variables show the greatest potential as predictors?

# %%
# Plotting scatterplots for categorical data

for column in all_cat_vars:
    plot= sns.stripplot(x=df[column],y=df['price'],marker='.') # kde=True,label = column+' histogram')
#     df[column].plot.hist(figsize=(8,5),bins=20,density=False,label = column+' histogram')
#     df[column].plot.kde(label =column+' kde')
    title = column+' Scatterplot'
#     if column == 'zipcode':
#         plot.set_xticklabels(rotation=90)

    plt.title(title.title())
#     plt.legend()
    plt.show()
# stats = plot_hist_scat(df_clean,'price')

# %% [markdown]
# #### ANSWER 3:
# **Notes on categorical scatter plots**
# - grade seems to be strongly related to price (notice how the whole range of values seems to increase in price at higher grades.
# - Zipcodes look to differ quite a bit in terms of price.
# - Condition looks to be highly related to price (at least above condition level 2)
# - View does not look as strongly related to price as I expected.
# - Floors do not seem as related as expected
# - yr_built may have some relationship with price
# - yr_renovated has somewhat of a trend, but recent renovations buck this trend

# %% [markdown]
# ## Normalizing and transforming data
# - log-transform and z-score numerical data.
#     - Debating whether to remove outliers using >3 Z-scores as criteria

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 24 columns):
# date                 21143 non-null datetime64[ns]
# price                21143 non-null float64
# bedrooms             21143 non-null int64
# bathrooms            21143 non-null float64
# sqft_living          21143 non-null int64
# sqft_lot             21143 non-null int64
# floors               21143 non-null float64
# waterfront           21143 non-null float64
# view                 21143 non-null float64
# condition            21143 non-null int64
# grade                21143 non-null int64
# sqft_above           21143 non-null int64
# sqft_basement        21143 non-null float64
# yr_built             21143 non-null int64
# yr_renovated         21143 non-null float64
# zipcode              21143 non-null int64
# lat                  21143 non-null float64
# long                 21143 non-null float64
# sqft_living15        21143 non-null int64
# sqft_lot15           21143 non-null int64
# bins_yrbuilt         21059 non-null category
# bins_yrrenovated     21143 non-null category
# bins_sqftbasement    21143 non-null category
# bins_sqftabove       21143 non-null category
# dtypes: category(4), datetime64[ns](1), float64(9), int64(10)
# memory usage: 4.1 MB

# %%
# NORMALIZE NUMERICAL DATA
vars_to_norm = ['price']+list(num_vars)

# %%
# LOG TRANSFORM AND Z-SCORE DATA
col_names = vars_to_norm
df_norm = df[vars_to_norm].copy()
# df_norm.info()
for col in col_names:
    data_to_log = df.loc[df[col]>0]
    df_norm['logZ_'+col] = log_z(data_to_log[col])
#     df_norm['logZ_'+col] = log_z(df[col])
df_norm  = df_norm.filter(regex=('log'),axis=1)
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 5 columns):
# logZ_price            21143 non-null float64
# logZ_sqft_living      21143 non-null float64
# logZ_sqft_lot         21143 non-null float64
# logZ_sqft_living15    21143 non-null float64
# logZ_sqft_lot15       21143 non-null float64
# dtypes: float64(5)
# memory usage: 991.1 KB

# %%
df_norm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 5 columns):
# logZ_price            21143 non-null float64
# logZ_sqft_living      21143 non-null float64
# logZ_sqft_lot         21143 non-null float64
# logZ_sqft_living15    21143 non-null float64
# logZ_sqft_lot15       21143 non-null float64
# dtypes: float64(5)
# memory usage: 991.1 KB

# %%
# Plot the transformed data distibutions and scatter plots 
plot_hist_scat(df_norm,'logZ_price')
# Out:
#                     0         1             2
# 0              column  K_square         p-val
# 1          logZ_price   854.395  2.95471e-186
# 2    logZ_sqft_living   7.54955     0.0229422
# 3       logZ_sqft_lot    4002.9             0
# 4  logZ_sqft_living15   199.441   4.92083e-44
# 5     logZ_sqft_lot15   4117.22             0

# %%
# stop

# %% [markdown]
# # FIT AN INITIAL MODEL:

# %% [markdown]
# ## PRELIMINARY UNIVARIATE LINEAR REGRESSION MODELING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 24 columns):
# date                 21143 non-null datetime64[ns]
# price                21143 non-null float64
# bedrooms             21143 non-null int64
# bathrooms            21143 non-null float64
# sqft_living          21143 non-null int64
# sqft_lot             21143 non-null int64
# floors               21143 non-null float64
# waterfront           21143 non-null float64
# view                 21143 non-null float64
# condition            21143 non-null int64
# grade                21143 non-null int64
# sqft_above           21143 non-null int64
# sqft_basement        21143 non-null float64
# yr_built             21143 non-null int64
# yr_renovated         21143 non-null float64
# zipcode              21143 non-null int64
# lat                  21143 non-null float64
# long                 21143 non-null float64
# sqft_living15        21143 non-null int64
# sqft_lot15           21143 non-null int64
# bins_yrbuilt         21059 non-null category
# bins_yrrenovated     21143 non-null category
# bins_sqftbasement    21143 non-null category
# bins_sqftabove       21143 non-null category
# dtypes: category(4), datetime64[ns](1), float64(9), int64(10)
# memory usage: 4.1 MB

# %% [markdown]
# #### Code for applying LabelEncoder()
# ```python
# cat_vars = ['floors','bedrooms','bathrooms','grade','condition','view','waterfront','zipcode'] #,'yr_built','yr_renovated'] #'date'
# for var in cat_vars:
#     df_clean['lb_'+var] = lb_make.fit_transform(df_clean[var].astype('str'))
#     df_clean['lb_'+var] = df_clean['lb_'+var].astype('category')
# ```

# %% [markdown]
# ### CONCATENATING ANALYSIS DATASET

# %%
# List of variables to be dropped from analyses
# df_run = pd.concat([df_norm, df],axis=1).copy()
df_add = df[['bedrooms','bathrooms','floors']].copy()
df_run = pd.concat([df_norm,df_add],axis=1)

# Code to use later:
# to_drop = ['lat','long','sqft_above','sqft_basement']
# df_run.drop(to_drop,axis=1,inplace=True)

cat_vars = ['view','waterfront','condition','grade','zipcode','bins_yrbuilt','bins_yrrenovated','bins_sqftbasement','bins_sqftabove']
for var in cat_vars:
    df_run['cat_'+var] = lb_make.fit_transform(df[var].astype('str'))
    df_run['cat_'+var] = df_run['cat_'+var].astype('category')
    df_run['cat_'+var] = df_run['cat_'+var].cat.as_ordered()

# %%
df_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 17 columns):
# logZ_price               21143 non-null float64
# logZ_sqft_living         21143 non-null float64
# logZ_sqft_lot            21143 non-null float64
# logZ_sqft_living15       21143 non-null float64
# logZ_sqft_lot15          21143 non-null float64
# bedrooms                 21143 non-null int64
# bathrooms                21143 non-null float64
# floors                   21143 non-null float64
# cat_view                 21143 non-null category
# cat_waterfront           21143 non-null category
# cat_condition            21143 non-null category
# cat_grade                21143 non-null category
# cat_zipcode              21143 non-null category
# cat_bins_yrbuilt         21143 non-null category
# cat_bins_yrrenovated     21143 non-null category
# cat_bins_sqftbasement    21143 non-null category
# cat_bins_sqftabove       21143 non-null category
# dtypes: category(9), float64(7), int64(1)
# memory usage: 1.6 MB

# %%
# # Code to covert later
# df_run['cat_view'] = df_run['view'].astype('str')
# df_run['cat_waterfront'] = df_run['waterfront'].astype('str')
# df_run['cat_condition'] = df_run['condition'].astype('str')
# df_run['cat_grade'] = df_run['grade'].astype('str')
# df_run['cat_zipcode'] = df_run['zipcode'].astype('str')

# %%
df_run.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21143 entries, 0 to 21596
# Data columns (total 17 columns):
# logZ_price               21143 non-null float64
# logZ_sqft_living         21143 non-null float64
# logZ_sqft_lot            21143 non-null float64
# logZ_sqft_living15       21143 non-null float64
# logZ_sqft_lot15          21143 non-null float64
# bedrooms                 21143 non-null int64
# bathrooms                21143 non-null float64
# floors                   21143 non-null float64
# cat_view                 21143 non-null category
# cat_waterfront           21143 non-null category
# cat_condition            21143 non-null category
# cat_grade                21143 non-null category
# cat_zipcode              21143 non-null category
# cat_bins_yrbuilt         21143 non-null category
# cat_bins_yrrenovated     21143 non-null category
# cat_bins_sqftbasement    21143 non-null category
# cat_bins_sqftabove       21143 non-null category
# dtypes: category(9), float64(7), int64(1)
# memory usage: 1.6 MB

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import statsmodels.stats.api as sms


# Running simple lin reg for each
# log_price = np.log(df['price'])
# df['log_price'] = log_price

target_var = 'logZ_price'
# col_names = df_run.describe().columns.drop(['price','logz_price']) 
col_names = df_run.columns

results = [['ind_var', 'r_squared', 'intercept', 'slope', 'p-value' ]] 
# print(results)
for idx, val in enumerate(col_names): 
#     print ("Price vs ~" + val) 
#     print ("------------------------------") 
    
    if val.startswith('cat_'):
        f =f'{str(target_var)}~C({val})'
    elif val.startswith('bin'):
        f =f'{str(target_var)}~C({val})'
    else:
        f =f'{str(target_var)}~{val}'
    model = smf.ols(formula=f, data=df_run).fit() 
    X_new = pd.DataFrame({val: [df_run[val].min(), df_run[val].max()]}); 
    preds = model.predict(X_new) 
    results.append([val, model.rsquared, model.params[0], model.params[1], model.pvalues[1] ]) 
#     print(results[idx+1])
    model.summary()
#     input('Press enter...')
pd.DataFrame(results)
# Out:
#                         0          1            2          3             4
# 0                 ind_var  r_squared    intercept      slope       p-value
# 1              logZ_price          1 -5.16948e-16          1             0
# 2        logZ_sqft_living   0.455157 -5.16948e-16   0.674654             0
# 3           logZ_sqft_lot  0.0191448 -5.16948e-16   0.138365   7.19015e-91
# 4      logZ_sqft_living15   0.369609 -5.16948e-16   0.607955             0
# 5         logZ_sqft_lot15  0.0154522 -5.16948e-16   0.124307   1.42275e-73
# 6                bedrooms    0.11771     -1.25105   0.370949             0
# 7               bathrooms   0.303706     -1.51743   0.717093             0
# 8                  floors  0.0961681     -0.85895    0.57509             0
# 9                cat_view   0.122859    -0.108224   0.892787   4.80843e-65
# 10         cat_waterfront  0.0291229   -0.0140327    2.08939  6.70488e-138
# 11          cat_condition  0.0141235     -1.04854  0.0620148      0.759852
# 12              cat_grade   0.497033      1.43133   0.624772   1.81301e-50
# 13            cat_zipcode   0.530834     -1.04813   -0.29961    8.7948e-07
# 14       cat_bins_yrbuilt   0.057546     0.328863  -0.262334   3.50449e-07
# 15   cat_bins_yrrenovated  0.0147364    -0.284215    -0.2929      0.686244
# 16  cat_bins_sqftbasement   0.104306   -0.0838617   0.763559   4.3347e-134
# 17     cat_bins_sqftabove   0.352078      -1.5167    1.12025   1.42002e-09

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             logZ_price   R-squared:                       0.352
# Model:                            OLS   Adj. R-squared:                  0.352
# Method:                 Least Squares   F-statistic:                     637.7
# Date:                Mon, 11 Mar 2019   Prob (F-statistic):               0.00
# Time:                        17:31:58   Log-Likelihood:                -25413.
# No. Observations:               21143   AIC:                         5.086e+04
# Df Residuals:                   21124   BIC:                         5.101e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -1.5167      0.185     -8.210      0.000      -1.879      -1.155
# C(cat_bins_sqftabove)[T.1]      1.1203      0.185      6.056      0.000       0.758       1.483
# C(cat_bins_sqftabove)[T.2]      1.5187      0.185      8.204      0.000       1.156       1.882
# C(cat_bins_sqftabove)[T.3]      1.8355      0.185      9.901      0.000       1.472       2.199
# C(cat_bins_sqftabove)[T.4]      2.1620      0.186     11.642      0.000       1.798       2.526
# C(cat_bins_sqftabove)[T.5]      2.5189      0.186     13.517      0.000       2.154       2.884
# C(cat_bins_sqftabove)[T.6]      2.9601      0.188     15.707      0.000       2.591       3.330
# C(cat_bins_sqftabove)[T.7]      3.3894      0.192     17.658      0.000       3.013       3.766
# C(cat_bins_sqftabove)[T.8]      3.7850      0.205     18.439      0.000       3.383       4.187
# C(cat_bins_sqftabove)[T.9]      0.8164      0.185      4.402      0.000       0.453       1.180
# C(cat_bins_sqftabove)[T.10]     3.8196      0.223     17.155      0.000       3.383       4.256
# C(cat_bins_sqftabove)[T.11]     4.2672      0.284     15.044      0.000       3.711       4.823
# C(cat_bins_sqftabove)[T.12]     4.6048      0.273     16.852      0.000       4.069       5.140
# C(cat_bins_sqftabove)[T.13]     4.5864      0.443     10.353      0.000       3.718       5.455
# C(cat_bins_sqftabove)[T.14]     3.7317      0.599      6.234      0.000       2.558       4.905
# C(cat_bins_sqftabove)[T.15]     5.3983      0.500     10.790      0.000       4.418       6.379
# C(cat_bins_sqftabove)[T.16]     5.2403      0.826      6.343      0.000       3.621       6.860
# C(cat_bins_sqftabove)[T.17]     6.7436      0.599     11.265      0.000       5.570       7.917
# C(cat_bins_sqftabove)[T.18]     4.5382      0.826      5.493      0.000       2.919       6.158
# ==============================================================================
# Omnibus:                      130.818   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.161
# Skew:                           0.194   Prob(JB):                     1.21e-29
# Kurtosis:                       2.971   Cond. No.                         189.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### NOTES FOLLOWING PRELIMINARY LINEAR REGRESSIONS
# - Variables that had high R_square with logz_price:
#
# ```python
#  try_modeling = ['logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms','cat_grade','cat_zipcode','cat_view','cat_bins_sqft_above','cat_bins_sqft_basement']
#
# ```

# %% [markdown]
# ## MULTIVARIATE REGRESSIONS

# %%
# PUTTING TOGETHER THE PREDICTORS TO RUN IN THE REGRESSION
## Last min dummy vars []'cat_grade','cat_zipcode','cat_view','cat_bins_sqft_above','cat_bins_sqft_basement']
dum_grades = pd.get_dummies(df_run['cat_grade'],prefix='gr').iloc[:,:-1]
dum_view = pd.get_dummies(df_run['cat_view'], prefix='view').iloc[:,:-1]
dum_sqft_above = pd.get_dummies(df_run['cat_bins_sqftabove'],prefix='sqftAb').iloc[:,:-1]
dum_sqft_base = pd.get_dummies(df_run['cat_bins_sqftbasement'],prefix='sqftBa').iloc[:,:-1]


# RUNNING K-FOLD VALIDATION WITH STATSMODELS OLS.
# X = df_run.drop(['price','logZ_price'],axis=1)
list_predictors = ['logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms','floors']
X = df_run[list_predictors]
X = pd.concat([X,dum_grades,dum_view,dum_sqft_above,dum_sqft_base],axis=1) #dum_bedrooms
y = df_run['logZ_price']

# %%
list_predictors = [str(x) for x in X.columns]
# reg_params = ['intercept']
# reg_params.append(list_predictors)
list_predictors.append('intercept')
list_predictors
# Out:
# ['logZ_sqft_living',
#  'logZ_sqft_living15',
#  'bedrooms',
#  'bathrooms',
#  'floors',
#  'gr_0',
#  'gr_1',
#  'gr_2',
#  'gr_3',
#  'gr_4',
#  'gr_5',
#  'gr_6',
#  'gr_7',
#  'gr_8',
#  'gr_9',
#  'view_0',
#  'view_1',
#  'view_2',
#  'view_3',
#  'sqftAb_0',
#  'sqftAb_1',
#  'sqftAb_2',
#  'sqftAb_3',
#  'sqftAb_4',
#  'sqftAb_5',
#  'sqftAb_6',
#  'sqftAb_7',
#  'sqftAb_8',
#  'sqftAb_9',
#  'sqftAb_10',
#  'sqftAb_11',
#  'sqftAb_12',
#  'sqftAb_13',
#  'sqftAb_14',
#  'sqftAb_15',
#  'sqftAb_16',
#  'sqftAb_17',
#  'sqftBa_0',
#  'sqftBa_1',
#  'sqftBa_2',
#  'sqftBa_3',
#  'sqftBa_4',
#  'sqftBa_5',
#  'sqftBa_6',
#  'sqftBa_7',
#  'intercept']

# %%
# DEFINING FUNCTION TO RUN K-FOLD VALIDATION
def k_fold_val(X,y,k=10):
    from sklearn.model_selection import train_test_split
    from sklearn.linear_model import LinearRegression
    from sklearn import metrics 

    # Run 10-fold cross validation
    i=0
    results = [['set#','R_square_train','MSE_train','R_square_test','MSE_test']]
    
    num_coeff = X.shape[1]
    
    list_predictors = [str(x) for x in X.columns]
    # reg_params = ['intercept']
    # reg_params.append(list_predictors)
    list_predictors.append('intercept') 
    reg_params = [list_predictors]
    while i <(k+1):
        X_train, X_test, y_train, y_test = train_test_split(X,y) #,stratify=[cat_col_names])


        linreg = LinearRegression()
        linreg.fit(X_train, y_train)


        y_hat_train = linreg.predict(X_train)
        y_hat_test = linreg.predict(X_test)

        train_residuals = y_hat_train - y_train
        test_residuals = y_hat_test - y_test

        train_mse = metrics.mean_squared_error(y_train, y_hat_train)
        test_mse = metrics.mean_squared_error(y_test, y_hat_test)

        R_sqare_train = metrics.r2_score(y_train,y_hat_train)
        R_square_test = metrics.r2_score(y_test,y_hat_test)

        results.append([i,R_sqare_train,train_mse,R_square_test,test_mse])
        params_to_add = [x for x in linreg.coef_]
        params_to_add.append(linreg.intercept_)
        reg_params.append(params_to_add)

        i +=1
    df_res=pd.DataFrame(results)
    df_reg_params = pd.DataFrame(reg_params)

    r2_test = np.array(df_res.iloc[1:,3]).mean()
    MSE_test = np.array(df_res.iloc[1:,4]).mean()
    
    print(f'For k={k}: mean r2 = {round(r2_test,3)}, mean MSE = {round(MSE_test,3)}')

    return df_res, df_reg_params

# %%
# Output 1:
df_res,df_params = k_fold_val(X,y)
df_res
# Out:
# For k=10: mean r2 = 0.588, mean MSE = 0.407
#        0               1          2              3         4
# 0   set#  R_square_train  MSE_train  R_square_test  MSE_test
# 1      0        0.592797   0.409204       0.601045  0.393072
# 2      1        0.596293   0.405014        0.58989  0.406095
# 3      2        0.601025   0.407266       0.574318  0.398946
# 4      3        0.595425   0.404291       0.592567  0.408269
# 5      4        0.595138    0.40571       0.594307  0.403114
# 6      5        0.601515   0.403858       0.574263  0.408503
# 7      6        0.597199   0.403037       0.587371  0.411862
# 8      7         0.59358   0.402118       0.598706  0.414014
# 9      8        0.601928   0.400376       0.573135  0.419233
# 10     9        0.600196   0.403113       0.578507  0.410938
# 11    10        0.593067   0.406106       0.600081  0.402355

# %%
df_params
# Out:
#                   0                   1           2          3          4   \
# 0   logZ_sqft_living  logZ_sqft_living15    bedrooms  bathrooms     floors
# 1           0.150586            0.120062 -0.00998953 -0.0616439   0.112675
# 2           0.173788            0.116329  -0.0151972 -0.0586132    0.12588
# 3           0.166683            0.105965   -0.019944 -0.0510322   0.117324
# 4            0.17372            0.106271   -0.029832 -0.0493966  0.0923591
# 5           0.160325            0.110253  -0.0101676 -0.0618346   0.123609
# 6           0.151043            0.114725  -0.0133391 -0.0539257   0.117998
# 7           0.165044            0.104529  -0.0150804 -0.0507331   0.106957
# 8           0.153451            0.108027  -0.0228306 -0.0514539   0.119282
# 9           0.173103            0.103732  -0.0142655 -0.0462985   0.110964
# 10           0.16145            0.119795  -0.0157838 -0.0577099   0.123168
# 11            0.1394            0.110442  -0.0142622 -0.0543579   0.116765
#
#           5         6         7        8            9   ...         36  \
# 0       gr_0      gr_1      gr_2     gr_3         gr_4  ...  sqftAb_17
# 1   0.329094  0.565677  0.908884  1.18561    -0.865953  ...    1.30331
# 2   0.302114  0.558161  0.895453   1.6732    -0.808894  ...    1.06793
# 3   0.321235  0.521859  0.881476  1.37387    -0.841315  ...    1.19511
# 4   0.272481  0.537931  0.850991  1.38157    -0.865992  ...    1.08305
# 5   0.312878  0.541074   0.85108  1.31364    -0.879252  ...    1.12551
# 6   0.314617  0.556219  0.862152  1.25446    -0.877645  ...    1.12966
# 7   0.316448  0.611811  0.929159  1.37114 -4.38538e-15  ...    1.00498
# 8   0.332885  0.577379  0.852739  1.08887    -0.868462  ...    1.55776
# 9     0.3176  0.556724  0.970877  1.30215    -0.815395  ...    1.15423
# 10  0.308189  0.576816   1.00002  1.38389  1.16573e-15  ...    1.36814
# 11   0.30314  0.535428  0.848351  1.15077    -0.885451  ...    1.16845
#
#           37        38        39        40         41        42        43  \
# 0   sqftBa_0  sqftBa_1  sqftBa_2  sqftBa_3   sqftBa_4  sqftBa_5  sqftBa_6
# 1   0.280679  0.456635  0.471876   0.54455   0.436421  0.764167  -0.45292
# 2   0.272893  0.429503  0.519921  0.494429   0.209324  0.693588         0
# 3   0.293306  0.450198  0.513544  0.486663   0.194461  0.732985         0
# 4   0.273896  0.438689  0.478393   0.50203  0.0912467  0.844466 -0.365359
# 5   0.267769  0.446407  0.519937  0.475764   0.211862  0.809897         0
# 6   0.280703  0.452733  0.493856  0.448374   0.450838  0.889544         0
# 7   0.265971  0.425593  0.519568  0.491595    0.35908  0.629527         0
# 8   0.274857  0.471107  0.496681  0.523625  0.0886787  0.705119         0
# 9   0.279001  0.434158  0.455213  0.447765   0.262424   0.68995 -0.596012
# 10  0.290818   0.44876   0.49872  0.419979   0.101987  0.610761 -0.638725
# 11  0.293923  0.482792  0.536514  0.448253   0.599346  0.774128         0
#
#           44         45
# 0   sqftBa_7  intercept
# 1   0.354324    1.74647
# 2   0.332595    1.67894
# 3   0.363469    1.79039
# 4   0.338824    1.75148
# 5   0.342985    1.73629
# 6   0.363668    1.77096
# 7   0.336931    1.66668
# 8    0.36293    1.79396
# 9   0.338313    1.68289
# 10  0.358311    1.76924
# 11  0.367317    1.75373
#
# [12 rows x 46 columns]

# %% [markdown]
# **Output 1:**
# - Predictors :
#     - logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms','floors', cat_grade, cat_view, cat_bins_sqftabove, cat_bins_sqftbasement]
# - For k=10: mean r2 = 0.595, mean MSE = 0.407
# - X_cats = df_run[['logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms','floors', 'cat_grade', 'cat_view',\
#                 'cat_bins_sqftabove', 'cat_bins_sqftbasement']]
# - Realized did not have zipcodes included, adding to model and trying again.

# %%
# MODEL #2
# PUTTING TOGETHER THE PREDICTORS TO RUN IN THE REGRESSION
## Last min dummy vars []'cat_grade','cat_zipcode','cat_view','cat_bins_sqft_above','cat_bins_sqft_basement']
dum_grades = pd.get_dummies(df_run['cat_grade'],prefix='gr').iloc[:,:-1]
dum_view = pd.get_dummies(df_run['cat_view'], prefix='view').iloc[:,:-1]
dum_sqft_above = pd.get_dummies(df_run['cat_bins_sqftabove'],prefix='sqftAb').iloc[:,:-1]
dum_sqft_base = pd.get_dummies(df_run['cat_bins_sqftbasement'],prefix='sqftBa').iloc[:,:-1]
dum_zipcodes = pd.get_dummies(df_run['cat_zipcode'],prefix='zip').iloc[:,:-1]

# RUNNING K-FOLD VALIDATION.
# X = df_run.drop(['price','logZ_price'],axis=1)
list_predictors = ['logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms','floors']
X = df_run[list_predictors]
X = pd.concat([X,dum_grades,dum_view,dum_sqft_above,dum_sqft_base,dum_zipcodes],axis=1) #dum_bedrooms
y = df_run['logZ_price']

# Output 2:
df_res,df_params = k_fold_val(X,y)
df_res
# Out:
# For k=10: mean r2 = -3.0761117419347804e+20, mean MSE = 3.0777687546031237e+20
#        0               1          2              3            4
# 0   set#  R_square_train  MSE_train  R_square_test     MSE_test
# 1      0        0.872529   0.125903   -1.02453e+21  1.06189e+21
# 2      1         0.87271   0.125944       0.872678     0.131351
# 3      2        0.871187   0.128595   -9.10969e+19  9.15264e+19
# 4      3        0.873977   0.124943   -1.89875e+20  1.94678e+20
# 5      4        0.871216   0.128377   -6.73565e+19  6.79849e+19
# 6      5        0.874894   0.125509   -9.37303e+18  9.28095e+18
# 7      6        0.872733   0.128485   -6.77141e+20   6.5733e+20
# 8      7        0.873376   0.127311   -1.32195e+21  1.30043e+21
# 9      8        0.873607   0.127416       0.870145     0.126698
# 10     9         0.87334   0.126221   -2.40235e+18  2.42677e+18
# 11    10        0.866122   0.132939        0.86866     0.134093

# %%
df_params
# Out:
#                  0                   1          2          3         4    \
# 0   logZ_sqft_living  logZ_sqft_living15   bedrooms  bathrooms    floors
# 1           0.328629           0.0935475 -0.0226898  0.0432705 -0.128814
# 2           0.320332           0.0933351 -0.0202027  0.0460563 -0.132095
# 3           0.326907           0.0966638 -0.0193743  0.0453691 -0.129319
# 4           0.328921           0.0953931 -0.0268349  0.0503399 -0.121722
# 5           0.330914           0.0969849 -0.0161804  0.0462546 -0.128875
# 6           0.320882           0.0910926 -0.0183019   0.033825  -0.12408
# 7           0.332331            0.100032 -0.0202731  0.0429077 -0.125479
# 8           0.327201           0.0923881 -0.0228771  0.0427029 -0.121395
# 9           0.329913           0.0950992 -0.0193988  0.0442354  -0.12221
# 10          0.320211           0.0930661 -0.0225948   0.045128 -0.134398
# 11          0.322916           0.0810444 -0.0181532  0.0317088 -0.116775
#
#          5         6         7         8           9    ...      105      106  \
# 0       gr_0      gr_1      gr_2      gr_3        gr_4  ...   zip_60   zip_61
# 1   0.179355  0.369233  0.608491  0.977525    0.673753  ... -1.10941 -1.34304
# 2   0.173462  0.346472  0.533722   0.89365    0.474221  ... -1.09414 -1.33213
# 3   0.181518  0.368523  0.659506   1.04619    0.484412  ...  -1.0999 -1.32557
# 4   0.158401  0.364274  0.528959  0.973723    0.425462  ... -1.14694 -1.33229
# 5   0.174267  0.361313  0.572025  0.649967    0.584339  ... -1.11986 -1.36864
# 6    0.16581   0.37042   0.52591  0.765536    0.525812  ... -1.14709 -1.42495
# 7   0.183653  0.350401  0.561884   1.17579     0.96645  ... -1.14651 -1.38701
# 8   0.150272  0.343603  0.538038   0.89036    0.716624  ... -1.11422 -1.31279
# 9   0.170668  0.346958  0.545087  0.884194    0.679796  ... -1.11663 -1.37546
# 10  0.169846  0.348054   0.62729  0.977743  1.1326e+11  ... -1.12006 -1.43694
# 11   0.15671  0.330579  0.529398   1.14698     0.95995  ... -1.14331 -1.54041
#
#          107       108      109       110      111      112      113  \
# 0     zip_62    zip_63   zip_64    zip_65   zip_66   zip_67   zip_68
# 1  -0.801642  -1.00862 -1.47395 -0.551915  -1.3629 -1.43115 -1.48021
# 2  -0.789513 -0.964081 -1.48389 -0.550042 -1.35579 -1.45964  -1.4877
# 3  -0.791206  -1.01856 -1.47079 -0.540265 -1.36883 -1.44444 -1.52273
# 4  -0.826823  -1.01512 -1.50112 -0.563238 -1.34133 -1.46036 -1.49536
# 5  -0.828234   -1.0533 -1.45442 -0.556693 -1.37798 -1.46511 -1.52402
# 6  -0.827113  -1.01995 -1.50055 -0.557596 -1.39358 -1.45586 -1.51099
# 7   -0.82231  -1.03794 -1.53643 -0.577136 -1.37972 -1.44449 -1.53339
# 8  -0.828926   -1.0286 -1.45849 -0.579598 -1.36315 -1.43661 -1.52333
# 9  -0.807971  -1.00627  -1.5279 -0.546691 -1.38371 -1.43733 -1.51173
# 10 -0.812538  -1.04619 -1.50666 -0.558753 -1.39306  -1.4274 -1.53066
# 11 -0.826318  -1.07496 -1.63632 -0.548632 -1.54793 -1.54067 -1.63391
#
#             114
# 0     intercept
# 1  -1.16462e+12
# 2   3.57709e+12
# 3  -6.78848e+11
# 4   8.79233e+11
# 5  -1.38865e+12
# 6  -2.17083e+11
# 7   2.44554e+12
# 8   2.71833e+12
# 9  -1.33338e+12
# 10 -1.02923e+09
# 11 -2.48694e+12
#
# [12 rows x 115 columns]

# %% [markdown]
# **Output 2:**
# - Predictors :
#     - df_run[['logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms','floors', 'cat_grade', 'cat_view',\
#                 'cat_bins_sqftabove', 'cat_bins_sqftbasement','cat_zipcode']]
#
# - For k=10: mean r2 = -5.98119975258282e+20, mean MSE = 5.910069200674956e+20
# - Clearly adding zipcodes in was a mistake. I wasn't aware you could get a negative R-square value
#
# - For next iteration, will remove zipcodes, and will remove logZ_sqft_living since had correlation with sqftabove

# %%
# MODEL #3
# PUTTING TOGETHER THE PREDICTORS TO RUN IN THE REGRESSION
## Last min dummy vars []'cat_grade','cat_zipcode','cat_view','cat_bins_sqft_above','cat_bins_sqft_basement']
dum_grades = pd.get_dummies(df_run['cat_grade'],prefix='gr').iloc[:,:-1]
dum_view = pd.get_dummies(df_run['cat_view'], prefix='view').iloc[:,:-1]
dum_sqft_above = pd.get_dummies(df_run['cat_bins_sqftabove'],prefix='sqftAb').iloc[:,:-1]
dum_sqft_base = pd.get_dummies(df_run['cat_bins_sqftbasement'],prefix='sqftBa').iloc[:,:-1]
# dum_zipcodes = pd.get_dummies(df_run['cat_zipcode'],prefix='zip').iloc[:,:-1]

# RUNNING K-FOLD VALIDATION.
# X = df_run.drop(['price','logZ_price'],axis=1)
list_predictors = ['logZ_sqft_living15','bedrooms','bathrooms','floors']
X = df_run[list_predictors]
X = pd.concat([X,dum_grades,dum_view,dum_sqft_above,dum_sqft_base],axis=1) #dum_bedrooms
y = df_run['logZ_price']

# Output 3:
df_res,df_params = k_fold_val(X,y)
df_res
# Out:
# For k=10: mean r2 = 0.594, mean MSE = 0.412
#        0               1          2              3         4
# 0   set#  R_square_train  MSE_train  R_square_test  MSE_test
# 1      0        0.588842   0.406343       0.606596  0.406976
# 2      1        0.592927   0.403648       0.595265  0.414803
# 3      2        0.596114    0.40399       0.585677  0.413943
# 4      3        0.598856   0.404374       0.577234  0.412555
# 5      4        0.596055   0.401824       0.585472  0.421038
# 6      5         0.59099   0.406156       0.599463  0.408885
# 7      6        0.593063   0.402838       0.595108  0.417122
# 8      7        0.593668   0.405687       0.591109  0.410818
# 9      8        0.591402   0.404283        0.59767  0.415006
# 10     9        0.589469     0.4078       0.605027  0.402856
# 11    10        0.593875   0.404218       0.592472  0.413253

# %%
df_params
# Out:
#                     0           1          2         3         4         5   \
# 0   logZ_sqft_living15    bedrooms  bathrooms    floors      gr_0      gr_1
# 1             0.122306  -0.0030823 -0.0333875  0.105099  0.308694  0.550985
# 2             0.128037  -0.0093016 -0.0453375  0.122017  0.306582   0.54134
# 3             0.124535 -0.00216981 -0.0466988  0.122552  0.323011  0.544756
# 4             0.123564  -0.0065183 -0.0421506  0.114282  0.334206  0.563826
# 5             0.122784  0.00441499   -0.04801  0.106299  0.329908   0.57402
# 6             0.125354 -0.00612644 -0.0380795  0.111482  0.302725  0.518149
# 7             0.123026 -0.00523023 -0.0462143  0.104096  0.303725    0.5686
# 8             0.124258 -0.00791963 -0.0403967  0.101209  0.324071  0.543492
# 9             0.121171  -0.0108732  -0.035911   0.11132  0.308981   0.55234
# 10            0.118471    -0.01453 -0.0464117  0.105877  0.322943  0.545942
# 11            0.118481 -0.00488856 -0.0443011  0.108682  0.319748  0.519212
#
#           6        7            8        9   ...         35        36  \
# 0       gr_2     gr_3         gr_4     gr_5  ...  sqftAb_17  sqftBa_0
# 1   0.959153  1.23413     -1.07836 -1.67921  ...    1.34547  0.324116
# 2   0.929601    1.265     -1.06873 -1.55689  ...    1.54689   0.33797
# 3   0.877205  1.31337     -1.06518 -1.75333  ...    1.12511   0.33528
# 4   0.946521  1.09165      -1.0582 -1.74518  ...    1.49246  0.349784
# 5   0.933066  1.21706  2.55351e-15 -1.82419  ...    1.64437  0.337515
# 6   0.898543    1.542     -1.07456 -1.81831  ...    1.17954  0.345634
# 7   0.844709  1.20793      -1.1018 -1.64623  ...    1.59617  0.342081
# 8   0.888201  1.54138  7.10543e-15  -1.7521  ...    1.27917  0.334074
# 9   0.891146  1.20806     -1.08375 -1.56014  ...    1.38409  0.330779
# 10  0.914907   1.4007  4.44089e-16  -1.5762  ...    1.48515  0.341289
# 11  0.912052  1.30426     -1.07974 -1.73627  ...    1.45599  0.332897
#
#           37        38        39        40        41         42        43  \
# 0   sqftBa_1  sqftBa_2  sqftBa_3  sqftBa_4  sqftBa_5   sqftBa_6  sqftBa_7
# 1   0.588723   0.68646  0.589145   0.42805  0.962406          0  0.468296
# 2   0.614624  0.706179  0.741409   0.42402   1.00741 -0.0522654  0.488816
# 3   0.634662  0.722385  0.752058  0.532965    0.9458          0  0.486223
# 4   0.640651  0.660709  0.725148  0.602662  0.993756  -0.134786  0.478954
# 5   0.619046  0.695125  0.715908  0.443281  0.919724  -0.142084  0.475936
# 6   0.627028  0.672607  0.689487  0.544793   1.02493  0.0556067  0.484909
# 7   0.626119  0.672317  0.755549  0.453795  0.945645          0  0.490477
# 8   0.606148   0.70499  0.585361  0.182825  0.943998 -0.0303277   0.47916
# 9   0.600318  0.646624  0.731036   0.74747   1.38409          0  0.484618
# 10  0.635976  0.718933  0.722709  0.567287  0.880736 -0.0692639  0.495139
# 11  0.626964  0.671233  0.559832  0.457352   1.01716   -0.12173  0.496205
#
#            44
# 0   intercept
# 1     1.87909
# 2     1.83567
# 3     1.84308
# 4     1.89243
# 5     1.90973
# 6     1.71792
# 7      1.9653
# 8     1.87928
# 9     1.69006
# 10    1.98864
# 11    1.95114
#
# [12 rows x 45 columns]

# %% [markdown]
# **Output 3:**
# - For k=10: mean r2 = 0.585, mean MSE = 0.408
# - Slightly worse than original model.
# - Adding back sqft_living, removing floors

# %%
# MODEL #4
# PUTTING TOGETHER THE PREDICTORS TO RUN IN THE REGRESSION
## Last min dummy vars []'cat_grade','cat_zipcode','cat_view','cat_bins_sqft_above','cat_bins_sqft_basement']
dum_grades = pd.get_dummies(df_run['cat_grade'],prefix='gr').iloc[:,:-1]
dum_view = pd.get_dummies(df_run['cat_view'], prefix='view').iloc[:,:-1]
dum_sqft_above = pd.get_dummies(df_run['cat_bins_sqftabove'],prefix='sqftAb').iloc[:,:-1]
dum_sqft_base = pd.get_dummies(df_run['cat_bins_sqftbasement'],prefix='sqftBa').iloc[:,:-1]
# dum_zipcodes = pd.get_dummies(df_run['cat_zipcode'],prefix='zip').iloc[:,:-1]

# RUNNING K-FOLD VALIDATION.
# X = df_run.drop(['price','logZ_price'],axis=1)
list_predictors = ['logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms']
X = df_run[list_predictors]
X = pd.concat([X,dum_grades,dum_view,dum_sqft_above,dum_sqft_base],axis=1) #dum_bedrooms
y = df_run['logZ_price']

# Output 4:
df_res,df_params = k_fold_val(X,y)
df_res
# Out:
# For k=10: mean r2 = 0.591, mean MSE = 0.409
#        0               1          2              3         4
# 0   set#  R_square_train  MSE_train  R_square_test  MSE_test
# 1      0        0.592921   0.403137       0.593053  0.418741
# 2      1        0.602048   0.404243       0.562706  0.416402
# 3      2        0.593151   0.405641       0.592749  0.410867
# 4      3        0.592334   0.406091       0.594023  0.410671
# 5      4        0.595088   0.402097       0.587166  0.421442
# 6      5        0.590906   0.407729       0.598004  0.406002
# 7      6        0.590574   0.412066       0.599842  0.392386
# 8      7        0.588018   0.408377       0.605583  0.404644
# 9      8        0.594774   0.408782       0.587265  0.401589
# 10     9        0.590384   0.408666       0.599636  0.403148
# 11    10        0.595533   0.406933       0.584586  0.407663

# %%
df_params
# Out:
#                   0                   1          2          3         4   \
# 0   logZ_sqft_living  logZ_sqft_living15   bedrooms  bathrooms      gr_0
# 1           0.158164            0.101548 -0.0236976  -0.028264  0.323024
# 2           0.145357             0.11044 -0.0199965 -0.0224362  0.316305
# 3           0.170937            0.103266 -0.0268362 -0.0206615   0.31134
# 4           0.168179           0.0922435 -0.0269858  -0.015453  0.318831
# 5           0.159987            0.104515  -0.025652 -0.0218497  0.311089
# 6           0.175189           0.0969813 -0.0188084  -0.022442  0.331444
# 7           0.159394           0.0999188 -0.0138771 -0.0255161  0.287159
# 8           0.157171            0.102907  -0.026161 -0.0137272  0.317649
# 9           0.130544            0.108441 -0.0217417 -0.0242428  0.311468
# 10          0.166692           0.0955868 -0.0219522  -0.011916  0.314401
# 11          0.136813            0.102969 -0.0116981 -0.0149067  0.311094
#
#           5         6        7            8        9   ...           35  \
# 0       gr_1      gr_2     gr_3         gr_4     gr_5  ...    sqftAb_17
# 1   0.566234  0.987312  1.42472 -3.83027e-15 -1.60166  ...      1.12991
# 2   0.606279   1.01622  1.41192 -7.04992e-15 -1.57884  ...     0.826254
# 3    0.57106  0.885742  1.15244    -0.902349  -1.6251  ...      1.57064
# 4   0.575413  0.968035  1.45862  5.44009e-15 -1.42666  ...     0.870229
# 5   0.555161  0.971583  1.43299    -0.898906 -1.58987  ...      1.06781
# 6    0.57635   1.01195  1.44725    -0.862106 -1.66828  ...      1.20725
# 7   0.579927   0.87774  1.25154    -0.905859 -1.65358  ...  2.22045e-16
# 8   0.567816    0.9597  1.55123    -0.877518 -1.54473  ...     0.818946
# 9   0.607681  0.961205  1.37224    -0.937512 -1.72323  ...      1.11027
# 10  0.594212  0.880412  1.71664    -0.866229 -1.74172  ...     0.529611
# 11  0.563451  0.929184  1.34838    -0.913304 -1.68255  ...      1.09805
#
#           36        37        38        39         40        41        42  \
# 0   sqftBa_0  sqftBa_1  sqftBa_2  sqftBa_3   sqftBa_4  sqftBa_5  sqftBa_6
# 1   0.262967  0.401066  0.401829  0.360501  -0.120594  0.673925 -0.455856
# 2   0.280891  0.427463  0.444367  0.495199  0.0293576  0.520876 -0.554841
# 3    0.26045   0.37672  0.428185  0.386051  0.0528687   0.57567 -0.543574
# 4   0.268193  0.383365  0.427659   0.57905    0.11292  0.547368 -0.468073
# 5   0.255552   0.37502  0.424184  0.442291   0.111634  0.659005 -0.506987
# 6   0.267416  0.378618  0.429483  0.396131   0.220469  0.633407 -0.425432
# 7   0.267671  0.383859  0.416079  0.375099  -0.172518  0.570991 -0.487852
# 8   0.268096  0.401197  0.414016  0.321146   0.261857  0.640551         0
# 9   0.281794  0.438574  0.486534  0.400874   0.117385  0.743916 -0.424521
# 10  0.263226  0.388951  0.427547  0.191995 -0.0047447  0.568614 -0.462958
# 11  0.273581  0.410776  0.437912  0.467781   0.125353  0.712197         0
#
#           43         44
# 0   sqftBa_7  intercept
# 1   0.319952    1.85639
# 2   0.330905    1.88749
# 3   0.299622    1.94275
# 4    0.31671    1.78897
# 5   0.313789     1.8686
# 6   0.303487    1.65494
# 7     0.3109    1.90625
# 8   0.313122    1.72559
# 9   0.342749    1.91319
# 10  0.301832    1.80516
# 11  0.329975    1.84764
#
# [12 rows x 45 columns]

# %% [markdown]
# **Output 4:**
# - For k=10: mean r2 = 0.589, mean MSE = 0.411
# - slightly worse than original model
# - add back floors
# - add waterfront

# %%
# Model 5: 
# PUTTING TOGETHER THE PREDICTORS TO RUN IN THE REGRESSION
## Last min dummy vars []'cat_grade','cat_zipcode','cat_view','cat_bins_sqft_above','cat_bins_sqft_basement']
dum_grades = pd.get_dummies(df_run['cat_grade'],prefix='gr').iloc[:,:-1]
dum_view = pd.get_dummies(df_run['cat_view'], prefix='view').iloc[:,:-1]
dum_sqft_above = pd.get_dummies(df_run['cat_bins_sqftabove'],prefix='sqftAb').iloc[:,:-1]
dum_sqft_base = pd.get_dummies(df_run['cat_bins_sqftbasement'],prefix='sqftBa').iloc[:,:-1]
dum_waterfront = pd.get_dummies(df_run['cat_waterfront'],prefix='wat').iloc[:,:-1]



# RUNNING K-FOLD VALIDATION WITH STATSMODELS OLS.
# X = df_run.drop(['price','logZ_price'],axis=1)
list_predictors = ['logZ_sqft_living','logZ_sqft_living15','bedrooms','bathrooms','floors']
X = df_run[list_predictors]
X = pd.concat([X,dum_grades,dum_view,dum_sqft_above,dum_sqft_base,dum_waterfront],axis=1) #dum_bedrooms
y = df_run['logZ_price']

# Output 5:
df_res,df_params = k_fold_val(X,y)
df_res
# Out:
# For k=10: mean r2 = 0.592, mean MSE = 0.406
#        0               1          2              3         4
# 0   set#  R_square_train  MSE_train  R_square_test  MSE_test
# 1      0         0.60226   0.399674       0.580634  0.413249
# 2      1        0.594448   0.404226       0.603818  0.400026
# 3      2        0.600329   0.402398        0.58629  0.405122
# 4      3        0.592221   0.406057       0.610581  0.394349
# 5      4        0.603901   0.400518       0.575376  0.410233
# 6      5        0.600981   0.402019       0.584977  0.405656
# 7      6         0.59648   0.401591       0.598749  0.406999
# 8      7        0.595587    0.40439       0.601465  0.398585
# 9      8        0.600511   0.402584       0.585986  0.404351
# 10     9        0.598378   0.402022       0.592542    0.4062
# 11    10        0.597311   0.398248        0.59602  0.417343

# %%
df_params
# Out:
#                   0                   1           2          3         4   \
# 0   logZ_sqft_living  logZ_sqft_living15    bedrooms  bathrooms    floors
# 1           0.171618            0.108976  -0.0174385 -0.0671039  0.117683
# 2           0.135902            0.116207  -0.0200683 -0.0500507  0.105125
# 3           0.142576            0.120117 -0.00717393 -0.0587798  0.121571
# 4           0.158905            0.110445  -0.0165217 -0.0724049  0.113081
# 5           0.143384             0.10858 -0.00979908 -0.0555855  0.112656
# 6           0.144861            0.106215  -0.0170966 -0.0583714  0.105876
# 7           0.151248            0.112531  -0.0212237 -0.0533582  0.108314
# 8           0.167277            0.114345  -0.0159472 -0.0584235  0.117654
# 9           0.155072            0.105243  -0.0143887 -0.0596986  0.118979
# 10          0.152264             0.12037  -0.0144545 -0.0610226  0.116287
# 11          0.151478            0.110055  -0.0194867 -0.0471835  0.103636
#
#           5         6         7         8         9   ...        37        38  \
# 0       gr_0      gr_1      gr_2      gr_3      gr_4  ...  sqftBa_0  sqftBa_1
# 1   0.310205  0.552377   0.96932  0.943911 -0.850513  ...  0.269998  0.438187
# 2   0.293739  0.537783  0.851597   1.46566 -0.915045  ...  0.279698  0.457767
# 3    0.30272  0.518795  0.927188   1.22055  -0.84473  ...  0.281163  0.453543
# 4   0.307938  0.588908  0.882706   1.57789 -0.858089  ...  0.280581   0.44692
# 5   0.329117  0.594027  0.932529   1.42395 -0.871116  ...  0.304981  0.471437
# 6   0.330035  0.579077   0.89297   1.35809 -0.859331  ...  0.294178  0.463443
# 7   0.317823  0.577696  0.890899   1.34657 -0.872795  ...   0.28141  0.464481
# 8   0.313294  0.561994  0.893284   1.34445 -0.832892  ...  0.269556  0.444413
# 9   0.297766  0.560999   0.85477   1.35396 -0.861358  ...  0.283051  0.443346
# 10  0.302114  0.595812  0.943469   1.19334 -0.861087  ...   0.29229  0.445855
# 11  0.305259  0.482213   1.00209   1.36626 -0.893194  ...  0.269022  0.451803
#
#           39        40        41        42           43        44        45  \
# 0   sqftBa_2  sqftBa_3  sqftBa_4  sqftBa_5     sqftBa_6  sqftBa_7     wat_0
# 1   0.494267  0.385109  0.298753  0.387603  1.11022e-16  0.345534  -0.72143
# 2   0.532638   0.57067  0.331308  0.500082   -0.0637153  0.372245 -0.721166
# 3   0.545646  0.567051  0.190585  0.593568    -0.248236  0.362679 -0.653621
# 4   0.487463  0.489281  0.498524  0.483045   -0.0585753  0.361828 -0.680585
# 5   0.503254   0.56888  0.338495  0.549648    -0.138495  0.372369 -0.768431
# 6   0.521728  0.425368  0.333791  0.527708            0     0.385 -0.673861
# 7   0.577656  0.381618  0.342852  0.681808    -0.101151   0.36256 -0.732937
# 8   0.509258   0.48801  0.349818  0.553752 -2.22045e-16  0.341499  -0.62854
# 9   0.562584  0.615018  0.254452  0.532128    -0.184329  0.367217 -0.687849
# 10  0.501319   0.39991  0.215145   0.68117    -0.211529  0.342028 -0.681156
# 11   0.49129  0.488327  0.325539  0.533444    -0.320274  0.350848 -0.678322
#
#            46
# 0   intercept
# 1     2.28451
# 2     2.21528
# 3      2.1447
# 4     2.17879
# 5     2.19363
# 6     2.25135
# 7     2.18977
# 8      2.0773
# 9     2.23825
# 10    2.15844
# 11    2.20167
#
# [12 rows x 47 columns]

# %% [markdown]
# **Output 5:**
# - For k=10: mean r2 = 0.596, mean MSE = 0.405
# - Ever so slightly better than initial model.
#     - Do not have additional time to try other models.

# %% [markdown]
# # Final Model
# - For k=10 fold validation, with logZ_price as target variable:
#     - mean r2 = 0.596, mean MSE = 0.405
# - Predictors in final model:
#     - 'logZ_sqft_living'
#     - 'logZ_sqft_living15'
#     - 'bedrooms'
#     - 'bathrooms'
#     - 'floors'
#     - grade
#     - view
#     - sqft_above
#     - sqft_basement
#     - waterfront
#
# - My final model indicates that several aspects of the size of the house are important for determining price: (sqft) of the living areas, as well as the presence/size of basements, in addition to the # of floors, bedrooms, and bathrooms. Additionally, more qualitative aspects of the neighborhood/area also play and important role, such as if the house is waterfront property, the aesthetic quality of the view, as well as housing-grade

# %% [markdown]
# ## Predictor Coefficients & Their Affect On Sales Price
# - I admittedly do not know how to interpret the coefficients for dummy-coded variables, part of why I tried desperately to avoid them but couldn't resolve the sparse class issue when attempting to use test-train-split.
#     - They are all the same variable, and yet have wildly different coefficients.
# - However, I would say that housing grade seems to have a strong + relationship with sales price, the higher the grade the higher the sales price
# - The square footage of the living area is also + correlated with sales price.
# - The squarefootage of the basement also has a strong + relationship with salesprice.

# %% [markdown]
# # Future Directions
#
# - **With more time I would have proceeded to perform the following steps:**
#     - Additional changes to the predictors in the model
#         - Would have continued to remove some possibly confounding predictors, such as sqft_living vs sqft_above
#     - Applying different transformations to the data, such as removing outliers following Z-scoring (remove rows with absolute value Z-score > 3)
#     - I would have explored additional ways I could implement zipcode as a preditor. As-is it produced wildly unexpected results.
#         - Using latitude and longitude together to create clusters of values and examine housing price by regional clusters.
#     - I would further tweak the quality of the visuals, particularly changing the x-tick labels and rotation.
#     - I would also produce a multi-linear regression plot showing the predictors in the model.
#     - I would have spent additional time trying to run the multivariate regression in statsmodels, trying to fix the spare class issue that arises when attempting to stratify the predictors.
